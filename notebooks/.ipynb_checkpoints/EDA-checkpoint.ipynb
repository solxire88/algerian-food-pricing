# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/processed.csv")
df.head()
# Out:
#          date province   town   market  latitude  longitude  \
# 0  2015-04-15    Alger  Hydra  Algiers     36.75       3.04
# 1  2015-04-15    Alger  Hydra  Algiers     36.75       3.04
# 2  2015-04-15    Alger  Hydra  Algiers     36.75       3.04
# 3  2015-04-15    Alger  Hydra  Algiers     36.75       3.04
# 4  2015-04-15    Alger  Hydra  Algiers     36.75       3.04
#
#               category       commodity  price  usdprice unit  quantity
# 0   cereals and tubers           Pasta   60.0      0.61    g     500.0
# 1   cereals and tubers        Potatoes   80.0      0.81   kg       1.0
# 2   cereals and tubers            Rice   90.0      0.91   kg       1.0
# 3  meat, fish and eggs            Eggs  300.0      3.05  pcs      30.0
# 4  meat, fish and eggs  Meat (chicken)  277.0      2.81   kg       1.0

# %%
df.describe()
# Out:
#           latitude    longitude        price     usdprice     quantity
# count  4490.000000  4490.000000  4490.000000  4490.000000  4490.000000
# mean     27.941497    -7.189272   289.689931     2.223020    79.430958
# std       2.093744     2.443579   361.162287     2.691366   196.043439
# min      26.830000    -8.130000    10.000000     0.068000     1.000000
# 25%      27.490000    -8.010000   100.000000     0.840000     1.000000
# 50%      27.630000    -7.880000   150.000000     1.220000     1.000000
# 75%      27.680000    -7.830000   370.000000     2.980000    30.000000
# max      36.750000     3.040000  4000.000000    30.760000   800.000000

# %%
fig, ax = plt.subplots(2,2, figsize=(14,10))
ax = ax.flatten()

ax[0].set_title("Count by Province")
sns.countplot(data=df, x='province', ax=ax[0])
ax[1].set_title("Count by Province")
sns.countplot(data=df, x='town', ax=ax[1])
ax[2].set_title("Count by Province")
sns.countplot(data=df, x='market', ax=ax[2])
ax[3].set_title("Count by Province")
ax[3].tick_params(axis='x', rotation=45)
sns.countplot(data=df, x='category', ax=ax[3])
# Out:
# <Axes: title={'center': 'Count by Province'}, xlabel='category', ylabel='count'>

# %%
sns.lineplot(data=df, x='date', y='price')
# Out:
# <Axes: xlabel='date', ylabel='price'>
